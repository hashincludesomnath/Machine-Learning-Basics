# %%
# Computer Vision

# %% [markdown]
# !pip install opencv-python

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# **Create an array of random numbers from 0 - 100 with size of 10 x 10**

# %%
arr = np.random.randint(0,100,(10,10))
arr
# Out:
# array([[40, 63, 45, 26, 61, 80, 59, 92, 62, 75],
#        [15, 23, 37, 88, 89, 51, 82, 44,  5, 93],
#        [26, 70, 38, 96, 73, 72, 15, 16, 81, 47],
#        [86, 77, 91, 58, 65, 40,  0, 26, 14, 72],
#        [65, 24, 47, 80, 16, 59, 65, 71,  2, 49],
#        [54, 27,  1, 86, 62,  2, 61, 14, 31, 69],
#        [95, 99,  5, 24, 93,  2, 47, 49, 21, 23],
#        [75, 85, 12, 89,  0,  4, 38, 66, 49, 49],
#        [75, 26, 46, 77,  5, 69, 64,  6, 90, 67],
#        [88, 79,  2, 67, 11,  2, 20, 97, 43, 77]])

# %%
import seaborn as sns

# %%
plt.imshow(arr,cmap='gray')
plt.show()

# %%
#step 1 reading image

# %%
img = cv2.imread('image.jpg')

# %%
plt.imshow(img)

# %%
plt.
