# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = pd.read_csv('C:/Users/Som/Desktop/Datasets/Housing_Modified.csv',header=None)
dataset
# Out:
#          0        1         2        3        4         5        6         7   \
# 0     price  lotsize  bedrooms  bathrms  stories  driveway  recroom  fullbase
# 1     42000     5850         3        1      two       yes       no       yes
# 2     38500     4000         2        1      one       yes       no        no
# 3     49500     3060         3        1      one       yes       no        no
# 4     60500     6650         3        1      two       yes      yes        no
# 5     61000     6360         2        1      one       yes       no        no
# 6     66000     4160         3        1      one       yes      yes       yes
# 7     66000     3880         3        2      two       yes       no       yes
# 8     69000     4160         3        1    three       yes       no        no
# 9     83800     4800         3        1      one       yes      yes       yes
# 10    88500     5500         3        2     four       yes      yes        no
# ...

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 547 entries, 0 to 546
# Data columns (total 12 columns):
# 0     547 non-null object
# 1     547 non-null object
# 2     547 non-null object
# 3     547 non-null object
# 4     547 non-null object
# 5     547 non-null object
# 6     547 non-null object
# 7     547 non-null object
# 8     547 non-null object
# 9     547 non-null object
# 10    547 non-null object
# 11    547 non-null object
# dtypes: object(12)
# memory usage: 51.4+ KB
